# %% [markdown]
# # Homework 1: asteroid data

# %% [markdown]
# ## Part 1: loading and exploring the data

# %% [markdown]
# Load the data:

# %%
import numpy as np

# %%
np.genfromtxt?

# %%
data_raw = np.genfromtxt('asteroids5000.csv', delimiter=',')

# %% [markdown]
# Find out how many values are missing from the data:

# %%
np.isnan(data).sum()
# Out:
# 11241

# %% [markdown]
# Find out how many **rows** are complete, with no missing values:

# %%
data_raw[~np.isnan(data_raw).any(axis=1)].size
# Out:
# 5369

# %% [markdown]
# Create a new array containing only the rows with no missing values:

# %%
data = data_raw[~np.isnan(data_raw).any(axis=1)]

# %% [markdown]
# Compute the maximum, minimum, mean, and standard deviation of the values in each column:

# %% [markdown]
# **Maximum**

# %%
np.max(data, axis=0)
# Out:
# array([  4.28702303e+00,   3.71650568e-01,   3.48362566e+01,
#          1.29700000e+01,   9.52400000e+02,   1.07700000e+00,
#          6.55000000e-01])

# %% [markdown]
# **Minimum**

# %%
np.min(data, axis=0)
# Out:
# array([  1.86623082e+00,   2.70779650e-03,   2.64247752e-01,
#          3.20000000e+00,   7.23000000e+00,   5.80000000e-01,
#          1.20000000e-01])

# %% [markdown]
# **Mean**

# %%
np.mean(data, axis=0)
# Out:
# array([  2.84852694,   0.13989068,   9.74426393,   9.26473272,
#         78.08349413,   0.75930769,   0.35792047])

# %% [markdown]
# **Standard Deviation**

# %%
np.std(data, axis=0)
# Out:
# array([  0.38068924,   0.07057209,   6.25581047,   1.4261952 ,
#         65.20426683,   0.08407915,   0.08912981])

# %% [markdown]
# ## Part 2: Plotting the data

# %% [markdown]
# Display the column names for the dataset:

# %%
# !head -n1 asteroids5000.csv
# Out:
# #a,e,i,H,diameter,BV,UB

# %% [markdown]
# Here is what each column header represents:
# * **a** semi-major axis (AU)
# * **e** eccentricity
# * **i** inclination (deg)
# * **H** absolute magnitude parameter (mag)
# * **diameter** object diameter (km)
# * **BV**
# * **UB**

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# Plot the semi-major axis versus the sine of the inclination angle in radians.

# %%
plt.scatter(np.sin(np.deg2rad(data_raw[:,2])), data_raw[:,0]);
plt.xlabel('sine of inclination angle');
plt.ylabel('semi-major axis (AU)');

# %% [markdown]
# To do: Analyze what you observe, and describe what could explain this?

# %% [markdown]
# To do: Use plt.scatter to plot a color-magnitude diagram of the asteroids (H vs B-V). You should see two distinct "families" of asteroids indicated in this plot. Over-plot a line that divides these.

# %%
plt.scatter(data_raw[:,5], data_raw[:,3], c=data_raw[:,3]);
plt.xlabel('BV');
plt.ylabel('magnitude');

# %% [markdown]
# To do: Repeat the orbital parameter plot from above, but plot the two "families" from #4 in different colors. Note that this magnitude is undefined for many of the asteroids. Do you see any correlation between color and orbit?

# %% [markdown]
# To do: Compare what you found to plots in [Parker et al. 2008](http://adsabs.harvard.edu/abs/2008Icar..198..138P).  Note that we're not using the same data here, but we're looking at a similar collection of objects.
