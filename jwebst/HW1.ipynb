# %%
# %matplotlib inline
import numpy as np
import matplotlib as plt
ast=np.genfromtxt('../data/asteroids5000.csv',delimiter=',')

# %%
## How many missing values are in the data?
nNans=np.isnan(ast).sum()
print('There are '+str(nNans)+' nans in the data.')
# Out:
# There are 11241 nans in the data.

# %%
## How many row have no nans?
nanRows=np.isnan(ast).sum(axis=1)
isFullRow=[not(x) for x in nanRows]
nNoNanRows=sum(isFullRow)
print('There are '+str(nNoNanRows)+' rows with no missing data.')
# Out:
# There are 767 rows with no missing data.

# %%
## Make a new matrix with only objects without missing data
goodAst=ast[np.where(isFullRow),:].squeeze()

# %%
## compute the min, max, mean, and std of each column
x=np.random.random([2,3])
colMin =np.min (goodAst,axis=0)
colMax =np.max (goodAst,axis=0)
colMean=np.mean(goodAst,axis=0)
colStd =np.std (goodAst,axis=0)

print('the column minimums are ' +str(colMin ))
print('the column maximums are ' +str(colMax ))
print('the column means    are ' +str(colMean))
print('the column stds     are ' +str(colStd ))
# Out:
# the column minimums are [  1.86623082e+00   2.70779650e-03   2.64247752e-01   3.20000000e+00
#    7.23000000e+00   5.80000000e-01   1.20000000e-01]
# the column maximums are [  4.28702303e+00   3.71650568e-01   3.48362566e+01   1.29700000e+01
#    9.52400000e+02   1.07700000e+00   6.55000000e-01]
# the column means    are [  2.84852694   0.13989068   9.74426393   9.26473272  78.08349413
#    0.75930769   0.35792047]
# the column stds     are [  0.38068924   0.07057209   6.25581047   1.4261952   65.20426683
#    0.08407915   0.08912981]

# %%
# !head -n 1 ../data/asteroids5000.csv
# Out:
# #a,e,i,H,diameter,BV,UB

# %%
plt.pyplot.scatter(goodAst[:,0],np.sin(goodAst[:,2]*np.pi/180));
plt.pyplot.title('a vs sin(i)');
